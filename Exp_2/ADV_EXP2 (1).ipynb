# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('socio_profiles.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 62 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     66 non-null     object
#  1   Region                                                      66 non-null     object
#  2   Surface area (km2)                                          66 non-null     int64
#  3   Population in thousands (2017)                              66 non-null     int64
#  4   Population density (per km2, 2017)                          66 non-null     float64
#  5   Sex ratio (m per 100 f, 2017)                               66 non-null     float64
#  6   GDP: Gross domestic product (million current US$)           66 non-null     int64
#  7   GDP growth rate (annual %, const. 2005 prices)              66 non-null     float64
#  8   GDP per capita (current US$)                                66 non-null     float64
#  9   Economy: Agriculture (% of GVA)                             66 non-null     float64
#  10  Economy: Industry (% of GVA)                                66 non-null     float64
#  11  Economy: Services and other activity (% of GVA)             66 non-null     float64
#  12  Employment: Agriculture (% of employed)                     66 non-null     float64
#  13  Employment: Industry (% of employed)                        66 non-null     float64
#  14  Employment: Services (% of employed)                        66 non-null     float64
#  15  Unemployment (% of labour force)                            66 non-null     float64
#  16  Agricultural production index (2004-2006=100)               66 non-null     int64
#  17  Food production index (2004-2006=100)                       66 non-null     int64
#  18  International trade: Exports (million US$)                  66 non-null     int64
#  19  International trade: Imports (million US$)                  66 non-null     int64
#  20  International trade: Balance (million US$)                  66 non-null     int64
#  21  Balance of payments, current account (million US$)          66 non-null     int64
#  22  Population growth rate (average annual %)                   66 non-null     float64
#  23  Urban population (% of total population)_x                  66 non-null     float64
#  24  Urban population growth rate (average annual %)             66 non-null     float64
#  25  Fertility rate, total (live births per woman)               66 non-null     float64
#  26  Refugees and others of concern to UNHCR (in thousands)      66 non-null     float64
#  27  Infant mortality rate (per 1000 live births                 66 non-null     float64
#  28  Health: Total expenditure (% of GDP)                        66 non-null     float64
#  29  Health: Physicians (per 1000 pop.)                          66 non-null     object
#  30  Education: Government expenditure (% of GDP)                66 non-null     object
#  31  Seats held by women in national parliaments %               66 non-null     float64
#  32  Mobile-cellular subscriptions (per 100 inhabitants)         66 non-null     float64
#  33  Mobile-cellular subscriptions (per 100 inhabitants).1       66 non-null     float64
#  34  Individuals using the Internet (per 100 inhabitants)        66 non-null     int64
#  35  Threatened species (number)                                 66 non-null     float64
#  36  CO2 emission estimates (million tons/tons per capita)       66 non-null     int64
#  37  Energy production, primary (Petajoules)                     66 non-null     int64
#  38  Pop. using improved sanitation facilities (urban/rural, %)  66 non-null     object
#  39  Net Official Development Assist. received (% of GNI)        66 non-null     int64
#  40  Quality Of Life Index                                       66 non-null     float64
#  41  Purchasing Power Index                                      66 non-null     float64
#  42  Safety Index                                                66 non-null     float64
#  43  Health Care Index                                           66 non-null     float64
#  44  Cost of Living                                              66 non-null     float64
#  45  Property price to income ratio                              66 non-null     float64
#  46  Traffic commute time index                                  66 non-null     float64
#  47  Pollution index                                             66 non-null     float64
#  48  Climate index                                               66 non-null     float64
#  49  Gross Rental Yield City Center                              66 non-null     float64
#  50  Gross Rental Yield Outside Center                           66 non-null     float64
#  51  Property Price to Rent Ratio City Center                    66 non-null     float64
#  52  Property Price to Rent Ratio Outside Center                 66 non-null     float64
#  53  Mortgate as percentage of income                            66 non-null     float64
#  54  Affordability Index                                         66 non-null     float64
#  55  Cost Of Living Index                                        66 non-null     float64
#  56  Rent Index                                                  66 non-null     float64
#  57  Cost Of Living Plus Rent Index                              66 non-null     float64
#  58  Grocery Index                                               66 non-null     float64
#  59  Restaurant Price Index                                      66 non-null     float64
#  60  Local Purchasing Power Index                                66 non-null     float64
#  61  Access to electricity (% of population)                     66 non-null     float64
# dtypes: float64(44), int64(13), object(5)
# memory usage: 32.1+ KB

# %% [markdown]
# ###Word Chart

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Making it into a single string because wordcloud accepts it as that way.
text = " ".join(country for country in data['Region'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='hanning')
plt.axis('off')
plt.show()

# %% [markdown]
# ###Box and Whisker Plot

# %%
# Plot a boxplot for GDP per capita
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='GDP per capita (current US$)', data=data)
plt.xlabel('Region')
plt.ylabel('GDP per capita (current US$)')
plt.xticks(rotation=90)
plt.title('GDP per Capita by Region')
plt.show()

# %% [markdown]
# ###Violin Plot

# %%
# Plot a violin plot for GDP per capita
plt.figure(figsize=(14, 10))
sns.violinplot(x='Region', y='GDP per capita (current US$)', data=data)
plt.xticks(rotation=90)
plt.title('GDP per Capita by Region')
plt.show()

# %% [markdown]
# ###Regression Plot

# %%
# Linear regression plot for GDP per capita vs. Population density
sns.lmplot(x='Population density (per km2, 2017)', y='GDP per capita (current US$)', data=data)
plt.title('Linear Regression: GDP per Capita vs. Population Density')
plt.show()

# Nonlinear regression plot (e.g., quadratic)
sns.lmplot(x='Population density (per km2, 2017)', y='GDP per capita (current US$)', data=data, order=2)
plt.title('Nonlinear Regression: GDP per Capita vs. Population Density')
plt.show()

# %%
import plotly.express as px

fig = px.scatter_3d(data, x='GDP per capita (current US$)', y='Population density (per km2, 2017)', z='Unemployment (% of labour force)',
                    color='Region', size='Population in thousands (2017)', hover_data=['country'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52c1f8be-2b66-4e1a-ab27-ffca47abb031" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52c1f8be-2b66-4e1a-ab27-ffca47abb031")) {                    Plotly.newPlot(                        "52c1f8be-2b66-4e1a-ab27-ffca47abb031",                        [{"customdata":[["Argentina"],["Brazil"],["Chile"],["Colombia"],["Venezuela (Bolivarian Republic of)"]],"hovertemplate":"Region=SouthAmerica\u003cbr\u003eGDP per capita (current US$)=%{x}\u003cbr\u003ePopulation density (per km2, 2017)=%{y}\u003cbr\u003eUnemployment (% of labour force)=%{z}\u003cbr\u003ePopulation in thousands (2017)=%{marker.size}\u003cbr\u003ecountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SouthAmerica","marker":{"color":"#636efa","size":[44271,209288,18055,49066,31977],"sizemode":"area","sizeref":3523.7925,"symbol":"circle"},"mode":"markers","name":"SouthAmerica","scene":"scene","showlegend":true,"x":[14564.5,8528.3,13416.2,6056.1,11068.9],"y":[16.2,25.0,24.3,44.2,36.3],"z":[6.5,12.4,6.8,10.5,6.6],"type":"scatter3d"},{"customdata":[["Australia"],["New Zealand"]],"hovertemplate":"Region=Oceania\u003cbr\u003eGDP per capita (current US$)=%{x}\u003cbr\u003ePopulation density (per km2, 2017)=%{y}\u003cbr\u003eUnemployment (% of labour force)=%{z}\u003cbr\u003ePopulation in thousands (2017)=%{marker.size}\u003cbr\u003ecountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","marker":{"color":"#EF553B","size":[24451,4706],"sizemode":"area","sizeref":3523.7925,"symbol":"circle"},"mode":"markers","name":"Oceania","scene":"scene","showlegend":true,"x":[51352.2,38294.3],"y":[3.2,17.9],"z":[5.5,5.5],"type":"scatter3d"},{"customdata":[["Austria"],["Belgium"],["France"],["Germany"],["Netherlands"],["Switzerland"]],"hovertemplate":"Region=WesternEurope\u003cbr\u003eGDP per capita (current US$)=%{x}\u003cbr\u003ePopulation density (per km2, 2017)=%{y}\u003cbr\u003eUnemployment (% of labour force)=%{z}\u003cbr\u003ePopulation in thousands (2017)=%{marker.size}\u003cbr\u003ecountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"WesternEurope","marker":{"color":"#00cc96","size":[8736,11429,64980,82114,17036,8476],"sizemode":"area","sizeref":3523.7925,"symbol":"circle"},"mode":"markers","name":"WesternEurope","scene":"scene","showlegend":true,"x":[44117.7,40277.8,36304.2,41686.2,44332.1,80831.1],"y":[106.0,377.5,118.7,235.6,505.2,214.5],"z":[6.2,8.3,9.8,4.2,5.6,4.6],"type":"scatter3d"},{"customdata":[["Belarus"],["Bulgaria"],["Czechia"],["Hungary"],["Poland"],["Romania"],["Russian Federation"],["Slovakia"],["Ukraine"]],"hovertemplate":"Region=EasternEurope\u003cbr\u003eGDP per capita (current US$)=%{x}\u003cbr\u003ePopulation density (per km2, 2017)=%{y}\u003cbr\u003eUnemployment (% of labour force)=%{z}\u003cbr\u003ePopulation in thousands (2017)=%{marker.size}\u003cbr\u003ecountry=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EasternEurope","marker":{"color":"#ab63fa","size":[9468,7085,10618,9722,38171,19679,143990,5448,44223],"sizemode":"area","sizeref":3523.7925,"symbol":"circle"},"mode":"markers","name":"EasternEurope","scene":"scene","showlegend":true,"x":[5750.8,6846.8,17561.7,12350.6,12355.5,9120.7,9243.3,16082.5,2021.6],"y":[46.7,65.3,137.5,107.4,124.6,85.5,8.8,113.3,76.3],"z":[0.5,8.1,3.9,4.5,5.3,7.1,5.8,9.9,8.8],"type":"scatter3d"},{"customdata":[["Bosnia and Herzegovina"],["Croatia"],["Greece"],["Italy"],["Portugal"],["Serbia"],["Slovenia"],["Spain"],["The former Yugoslav Republic of Macedonia"]],"hovertemplate":"Region=SouthernEurope\u003cbr\u003eGDP per capita (current US$)=%{x}\u003cbr\u003ePopulation density (per km2, 2017)=%{y}\u003cbr\u003e ...

# %%
sns.stripplot(x='Region', y='GDP per capita (current US$)', data=data, jitter=True)
plt.xticks(rotation=90)
plt.title('Jitter Plot: GDP per Capita by Region')
plt.show()

# %%
# Example: Plotting GDP growth rate over time (assuming you have time-series data)
plt.figure(figsize=(10,8))
plt.plot(data['country'], data['GDP growth rate (annual %, const. 2005 prices)'])
plt.xticks(rotation=90)
plt.title('GDP Growth Rate by Country')
plt.show()

# %%
# Donut chart for Region distribution
plt.figure(figsize=(8, 8))
data['Region'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, wedgeprops={'width': 0.3})
plt.title('Donut Chart: Region Distribution')
plt.ylabel('')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate balance
Balance = np.array(Exports) - np.array(Imports)

# Create waterfall-like plot
cumulative = np.cumsum(Balance)
start_values = np.concatenate(([0], cumulative[:-1]))

fig, ax = plt.subplots()

for i in range(len(Balance)):
    color = 'green' if Balance[i] >= 0 else 'red'
    ax.bar(data.country[i], Balance[i], bottom=start_values[i], color=color)

ax.set_title('Waterfall Chart: Balance of Payments by Country')
ax.set_ylabel('Balance (million US$)')

plt.xticks(rotation=60)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3a596d64624e> in <cell line: 5>()
#       3
#       4 # Calculate balance
# ----> 5 Balance = np.array(Exports) - np.array(Imports)
#       6
#       7 # Create waterfall-like plot
#
# NameError: name 'Exports' is not defined
